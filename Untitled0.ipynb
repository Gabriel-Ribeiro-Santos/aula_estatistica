# %%
n1 = 100 # tamanho da amostra 1
x1 = 14.5 # media de idade da amostra 1
n2 = 150 # tamanho da amostra 2
x2 = 16.5 # media de idade da amostra 2
media_de_idade = (n1 * x1 + n2 * x2)/(n1 + n2)
print (media_de_idade)
# Out:
# 15.7

# %%
notas = [93, 82, 86, 75] # lista das notas de lucas
media_atual = sum(notas) / len(notas) # calculo da media atual
media_desejada = 86 # media deseajda 

# calculo da nota necessaria

nota_necessaria = (media_desejada * (len(notas) + 1)) - sum(notas)

print (" Lucas precisa tirar pelo menos", nota_necessaria, "na proxima prova")
# Out:
#  Lucas precisa tirar pelo menos 94 na proxima prova
